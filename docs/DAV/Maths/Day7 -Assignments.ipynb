# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Propbability of Netflix Subscribers

total_netflix_subscribers = 167000000 # Total number of Netflix subscribers
percentage_of_premium_subscribers = 0.2 # 20% of total subscribers are premium
percentage_of_basic_subscribers = 0.8 # 80% of total subscribers are basic
thriller_movie_premium = 0.8 # 80% of premium subscribers watch thriller movies
thriller_movie_basic = 0.5 # 50% of basic subscribers watch thriller movies

# %%
# Calculate the number of premium and basic subscribers
num_premium_subscribers = total_netflix_subscribers * percentage_of_premium_subscribers
num_basic_subscribers = total_netflix_subscribers * percentage_of_basic_subscribers

print(f"1. Total Subscribers: {total_netflix_subscribers} \n2. Premium Subscribers: {num_premium_subscribers} ,\n2. Basic Subscribers: {num_basic_subscribers}")

# Calculate the number of premium and basic subscribers who watch thriller movies
num_thriller_premium = num_premium_subscribers * thriller_movie_premium
num_thriller_basic = num_basic_subscribers * thriller_movie_basic

# Calculate the total number of subscribers who watch thriller movies
total_thriller_watchers = num_thriller_premium + num_thriller_basic

print(f"1. People who view thriller movies who are premium subscribers: {num_thriller_premium}, \n2. People who view thriller who are basic subscribers: {num_thriller_basic}, \n3. Total number of subscribers who watch thriller movies: {total_thriller_watchers}")

# Calculate the probability that a subscriber who watches thriller movies is a premium subscriber
probability_premium_given_thriller = num_thriller_premium / total_thriller_watchers

probability_premium_given_thriller

print(f"Probability that a subscriber who watches thriller movies is a premium subscriber: {probability_premium_given_thriller}")
# Out:
# 1. Total Subscribers: 167000000
# 2. Premium Subscribers: 33400000.0 ,
# 2. Basic Subscribers: 133600000.0
# 1. People who view thriller movies who are premium subscribers: 26720000.0,
# 2. People who view thriller who are basic subscribers: 66800000.0,
# 3. Total number of subscribers who watch thriller movies: 93520000.0
# Probability that a subscriber who watches thriller movies is a premium subscriber: 0.2857142857142857

# %% [markdown]
# Q3. Tea preference
#
#
# It is known that 70% people like plain tea, 60% people like ginger tea, and 30% like both.
#
# What percentage of the people like plain tea, but do not like ginger tea?

# %%
tea_consumers = 100
plain_tea_favourites = 0.7
ginger_tea_favourites = 0.6
plain_ginger_tea_favourites = 0.3

num_plain_tea_favourites = tea_consumers * plain_tea_favourites
num_ginger_tea_favourites = tea_consumers * ginger_tea_favourites
# Calculate the number of people who like both plain but not ginger tea
num_plain_not_ginger = num_plain_tea_favourites - (tea_consumers * plain_ginger_tea_favourites)     
num_plain_not_ginger
# Out:
# 40.0

# %% [markdown]
# Q4. Two dice sum - part 1
#
#
# Two dice are thrown, and their sum is recorded. What is the probability that the sum of observed oucome values is less than or equal to 5?

# %%
dice1 = 1/6
dice2 = 1/6

# calculate when Two dice are thrown, and their sum is recorded. What is the probability that the sum of observed oucome values is less than or equal to 5?
sum_less_than_5 = 0
for i in range(1,7): # Why it the range is 1 to 7?
    for j in range(1,7):
        if i+j <= 5:
            sum_less_than_5 += 1
sum_less_than_5
total_outcomes = 36
print(sum_less_than_5)
probability_sum_less_than_5 = sum_less_than_5 / total_outcomes

print(f"Probability that the sum of observed oucome values is less than or equal to 5: {probability_sum_less_than_5}")
# Out:
# 10
# Probability that the sum of observed oucome values is less than or equal to 5: 0.2777777777777778

# %% [markdown]
# Combined valiues
# 1,1
# 1,2
# 1,3
# 1,4

# %% [markdown]
# Q1. Colored T-shirts
#
# Neha has 4 yellow t-shirts, 6 black t-shirts, and 2 blue t-shirts to choose from for her outfit today. She chooses a t-shirt randomly with each t-shirt equally likely to be chosen.
# Find the probability that a black or blue t-shirt is chosen for the outfit.

# %%
# Probability formula : P(A U B) = P(A) + P(B) - P(A ∩ B)
total_tshirt = 12
blue_tshirt = 2
black_tshirt = 6
yello_tshirt = 4

# find the probability that a black or blue t-shirt is selected
total_black_or_blue = black_tshirt + blue_tshirt
print(f"total black or blue", {total_black_or_blue})

probability_black_or_blue = total_black_or_blue / total_tshirt
print(f"Probability that a black or blue t-shirt is selected: {probability_black_or_blue}")
# Out:
# total black or blue {8}
# Probability that a black or blue t-shirt is selected: 0.6666666666666666

# %% [markdown]
# Q2. 300 people
#
#
# Based on the table given below, solve the following:
# ![image.png](attachment:image.png)
#
#
# If a person is randomly selected out of 300 people, what is the probability that
#
# a. The person tested positive, given that he or she actually used marijuana?
#
# b. The person actually used marijuana, given that he or she tested positive?

# %%
total_persons = 300
positive_marijuana_yes= 119
positive_marijuana_no = 24
negative_marijuana_yes = 3
negative_marijuana_no = 154

# Calculate the person tested postive, given that he or she actually used mariguana
positive_marijuana = positive_marijuana_yes + positive_marijuana_no
positive_marijuana
probability_positive_marijuana = positive_marijuana_yes / negative_marijuana_yes 
print(f"Probability that a person tested positive, given that he or she actually used mariguana: {probability_positive_marijuana}")

# Calculate the person actually used mariguana, given that he or she tested positive
probability_marijuana_positive = positive_marijuana_yes / positive_marijuana
print(f"Probability that a person actually used mariguana, given that he or she tested positive: {probability_marijuana_positive}")
# Out:
# Probability that a person tested positive, given that he or she actually used mariguana: 39.666666666666664
# Probability that a person actually used mariguana, given that he or she tested positive: 0.8321678321678322

# %% [markdown]
# Q5. Elective choices - part 2
#
# Among 100 students, 60 have taken the computer vision (CV) module, 50 have taken natural language processing (NLP). Also, it is seen that 20 have taken both CV and NLP. Given that a person has taken NLP, what is the probability that he has also taken CV?

# %%
total_students = 100
cv_students = 50
nlp_students = 50
cv_nlp_students = 20


# calculate the probability that a student has taken nlp, given that he has taken also cv
probability_nlp_given_cv = cv_nlp_students / cv_students
print(f"Probability that a student has taken nlp, given that he has taken also cv: {probability_nlp_given_cv}")
# Out:
# Probability that a student has taken nlp, given that he has taken also cv: 0.4

# %% [markdown]
# Q6. Rare disease
#
# A rare disease affects only 1 out of 1000 people.
#
# Upon conducting a diagnostic test to detect it, it is found that 90% of the affected people get a "positive" test result and that 5% of the non-affected people also get "positive" test result.
#
# Given that a person tested positive, what is the probability that he is actually affected?

# %%
sample_space = 1000
disease_affecting = 1
disease_not_affecting = 999
positive_test_affecting = .9
positive_test_not_affecting = .5

# %% [markdown]
# character
# Hint 1
# Let B denote the event of getting a beginner cohort student,
# Let I denote the event of getting an intermediate cohort student, and
# Let A denote the event of getting an advanced cohort student.
#
# Then, according to the given statements:
# P(B) + P(I) = 0.75 [beginner or Intermediate]
# P(I) + P(A) = 0.6 [Intermediate or Advanced]
#
# Take 5-10 mins to reflect on the hint given and relate it to what you have learned to figure out the solution on your own. If you're still having trouble, then move on to the next hint. Remember that the more you challenge yourself to think critically about the concepts and solve problems on your own, the better you will understand and remember the material.

# %% [markdown]
# https://www.intmath.com/counting-probability/14-normal-probability-distribution.php

# %% [markdown]
# ![image.png](attachment:image.png)
