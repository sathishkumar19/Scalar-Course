# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Out:
# --2025-02-12 06:40:54--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.172.139.61, 18.172.139.210, 18.172.139.94, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.172.139.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6052052 (5.8M) [text/plain]
# Saving to: ‘clean_amazon_data.csv’
#
# clean_amazon_data.c 100%[===================>]   5.77M  4.11MB/s    in 1.4s
#
# 2025-02-12 06:40:56 (4.11 MB/s) - ‘clean_amazon_data.csv’ saved [6052052/6052052]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('clean_amazon_data.csv')
df.head()
# Out:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1737 entries, 0 to 1736
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  1737 non-null   object
#  1   user_id                     1737 non-null   object
#  2   user_name                   1737 non-null   object
#  3   review_id                   1737 non-null   object
#  4   review_title                1737 non-null   object
#  5   review_content              1737 non-null   object
#  6   order_timestamp             1737 non-null   object
#  7   product_name                1737 non-null   object
#  8   category                    1724 non-null   object
#  9   discounted_price            1724 non-null   float64
#  10  actual_price                1729 non-null   float64
#  11  rating                      1717 non-null   float64
#  12  rating_count                1735 non-null   float64
# ...

# %% [markdown]
# ---
#
#
#
# ## **1. Introduction to Data Visualization with Matplotlib and Seaborn 🚀**
#
# **📚 Context:**
#
# In this lecture, we will introduce two of the most popular Python libraries for data visualization: Matplotlib and Seaborn.
#
# You will learn how these tools can help transform complex datasets, like our E-commerce Review Dataset, into insightful visual representations. Let's begin with a solid foundation!

# %% [markdown]
# ### **1. What is Data Visualization? 📊**
#
# Data visualization is the art of representing data graphically. It allows us to:
# - **Summarize** large datasets efficiently.
# - **Spot patterns, trends, and anomalies**.
# - **Communicate insights to others**.
# - **Support decision-making processes**.
#
# ### Why Do We Need Data Visualization? 🧐
# 1. **Simplify Complex Data:** Our dataset has 30 columns and 1737 rows. Without visuals, identifying relationships and distributions is challenging.
# 2. **Highlight Insights:** For example, **understanding the distribution of ratings** or spotting **outliers in price** is much easier visually.
# 3. **Support Hypotheses:** Visuals help validate our assumptions (e.g., Are higher-priced products better rated?).

# %% [markdown]
# ### **2. Key Libraries for Visualization**
#
# ### Matplotlib 📈
# **Matplotlib** is a versatile library for creating 2D plots and graphs in Python.
# - **Modules:** The `pyplot` module is like the "Swiss Army knife" of visualization—it provides tools for making basic plots like line graphs, bar charts, and scatter plots.
# - **Customizability:** Highly customizable but can be verbose for more advanced visuals.
#
# ### Seaborn 🎨
# **Seaborn** is built on top of Matplotlib and is tailored for statistical data visualization.
# - **Enhanced Aesthetics:** Seaborn’s visuals are clean, professional, and easy to interpret.
# - **Pandas Integration:** It works seamlessly with Pandas DataFrames, making it ideal for datasets like ours.
# - **Advanced Features:** Built-in support for advanced plots like heatmaps, pair plots, and categorical plots.
#
# 💡 **Key Difference:** Matplotlib is great for full control and custom plots, while Seaborn simplifies and enhances plotting for statistical data.

# %% [markdown]
# **Instructor Note:**
#
# Throughout this lecture, we’ll:
# 1. Demonstrate each plot in <font color="greed">Seaborn</font> (where applicable).
# 2. Provide a small **styling tip** (💡).
# 3. Show an equivalent <font color="skyblue">Matplotlib</font> approach in a **note** when relevant.

# %% [markdown]
# ### **3. Anatomy of Matplotlib**
#
# <!-- <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/567/original/image_2022-11-10_121820129.png?1668062911"> -->
#
#
# <!-- <img src="https://files.realpython.com/media/fig_map.bc8c7cabd823.png" />
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/579/original/image_2022-11-10_150131378.png?1668072693"> -->
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/615/original/image_2022-11-11_112008033.png?1668145811">
#
# Woah! There is a lot of information in this image. Let's understand them one at a time.
#
# - Figure: The **overall window** or page that everything is drawn on.
#   - You can create multiple independent Figures in Jupyter.
#   - If you run the code in terminal, separate windows will pop-up.
# - Axes: You can add multiple **Axes** to the Figure, which represents a plot.
#
# - **Axis**: Simply the `x-axis` and `y-axis`
#
# - **Axes**: It is the **area** on which the **data is plotted** with functions such as `plot()`.
#     - **x-label**: Name of x-axis
#     - **y-label**: Name of y-axis
#
# - **Major ticks**:
#   - Subdivides the axis into major units.
#   - They appear by default during plotting.
# - **Minor ticks**:
#   - Subdivides the major tick units.
#   - They are by default hidden and can be toggled on.
#
# - **Title**: Title of each plot **(Axes)**
#
# - **Subtitle**: The common title of all the plots.
#
# - **Legend**:
#   - Describes the elements in the plot.
#   - Blue and Green curves in this case.
#
# These are the major components of a matplotlib plot.

# %% [markdown]
# ### **4. How to Choose the Right Plot? 🤔**
#
# Choosing the right plot depends on your **question of interest** and the nature of your data. Before selecting a visualization:
#
# 1. **What is the question you want to answer?**
# 2. **How many variables are involved?**
# 3. **Are the variables numerical or categorical?**
#
#
# ### Step 1: Number of Variables Involved
# The number of variables determines the type of analysis:
#
# - **1 Variable** → **Univariate Analysis**
# - **2 Variables** → **Bivariate Analysis**
# - **3+ Variables** → **Multivariate Analysis**

# %% [markdown]
# ## **2. Univariate Data Visualization 🎨**
#
# We start with univariate plots to understand **distributions** and **frequencies** of single columns.

# %% [markdown]
# ### 1 📊 Visualization Goal: Histogram
# A **histogram** helps visualize the distribution of a numerical column. Let’s explore the distribution of <font color="green">`rating`</font>.
#
# #### Key Insights
# - Identify skewness (are ratings generally high or low?).
# - Check for outliers or unusual spikes in values.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for 'rating'
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='rating', kde=False, color='skyblue')

# Styling Tip 💡
# Add a vertical line for the mean rating
mean_rating = df['rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {mean_rating:.2f}")

plt.title("Distribution of Ratings", fontsize=16)
plt.xlabel("Rating", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# - The mean rating of 4.11 suggests that customers generally have a positive perception of the products.
# - again most ratings are clustered around 4.0 to 4.5, with fewer low ratings.

# %% [markdown]
# Note: Equivalent in <font color="skyblue">Matplotlib</font>:

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['rating'].dropna(), bins=10, color='skyblue')
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {mean_rating:.2f}")
plt.title("Distribution of Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# - similarly here also we see the same very few ratings are below 3.5, meaning customers are unlikely to leave highly negative reviews.

# %% [markdown]
# ### 2 📊 Visualization Goal: Bar Plot (Categorical)
#
# A bar plot compares different categories, such as the count of products in each <font color="green">category</font>.
#
# **Key Insights**
# - Identify popular product categories.
#  -Useful for visualizing categorical data frequencies.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='category', palette='coolwarm')

# Styling Tip 💡
# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

plt.title("Count of Products by Category", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.show()

# %% [markdown]
# - this insight can lead to understanding of the market, which categories are sturated and which ones may have anoportunity for entry, later we can also see sales and otther numbers to decide if a category is growing or not.

# %% [markdown]
# Note: Equivalent in <font color="greed">Matplotlib</font>:

# %%
categories = df['category'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(categories.index, categories.values, color='skyblue')
plt.xticks(rotation=45)
plt.title("Count of Products by Category")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### **3. 📊 Visualization Goal: KDE (Kernel Density Estimate) Plot**
#
# A KDE plot is a smoothed version of the histogram. Let’s examine the distribution of <font color="green">discounted_price</font>.
#
# **Key Insights**
# - Easily see peaks and valleys in the distribution.
# - Compare with a histogram for a smoothed perspective.

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='discounted_price', shade=True, color='purple')

# Styling Tip 💡
# Add a vertical grid for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.title("KDE Plot of Discounted Prices", fontsize=16)
plt.xlabel("Discounted Price", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.show()

# %% [markdown]
# - The long tail in the plot suggests there are a small number of high-end products, but they are not common.
# - Since most products fall in the lower range, introducing well-targeted discount campaigns for mid-range products can help increase revenue.

# %% [markdown]
# Note: In <font color="greed">Matplotlib</font>, you could combine plt.hist with density=True and then plot a plt.plot of a KDE function from scipy.stats if needed.

# %% [markdown]
# ---
#
# ## **3. Bivariate Plots (Two Variables)**
#
# These plots help us understand relationships between two variables.

# %% [markdown]
# ### **1 📊 Visualization Goal: Scatter Plot**
#
# A scatter plot shows the relationship between two numerical variables. Let’s see if there’s a correlation between <font color="green">discounted_price</font> and <font color="green">rating</font>.
#
# **Key Insights**
# - Detect patterns (does a higher price correlate with higher ratings?).
# - Identify outliers (very high price but low rating, for example).

# %%
plt.figure(figsize=(8, 6))

# Styling Tip 💡
# Use alpha to handle overlapping points
sns.scatterplot(data=df, x='discounted_price', y='rating', color='teal', alpha = 0.8)

plt.title("Discounted Price vs. Rating", fontsize=16)
plt.xlabel("Discounted Price", fontsize=12)
plt.ylabel("Rating", fontsize=12)
plt.show()

# %% [markdown]
# - similar to what we saw earlier most products, regardless of price, have ratings concentrated around 4.0 - 5.0, suggesting overall customer satisfaction.
# - Since lower-priced products dominate in number of ratings, incentivize reviews for high-end products to increase credibility.

# %% [markdown]
# ### **2. 📊 Visualization Goal: Line Plot**
#
# A line plot often represents data over time. Let’s plot average <font color="green">rating_filled</font> by <font color="green">month_year</font> to see trends.
#
# **Key Insights**
# - Observe how ratings change month to month.
# - Could highlight seasonal spikes or dips.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by 'month_year' and calculate average rating
monthly_rating = df.groupby('month_year')['rating_filled'].mean().reset_index()

# Ensure 'month_year' is in datetime format
monthly_rating['month_year'] = pd.to_datetime(monthly_rating['month_year'], format='%B %Y')

# Sort the DataFrame based on 'month_year'
monthly_rating = monthly_rating.sort_values('month_year')

# Convert back to string for proper x-axis labels
monthly_rating['month_year'] = monthly_rating['month_year'].dt.strftime('%B %Y')

# Plot
plt.figure(figsize=(10, 6))
plt.plot(monthly_rating['month_year'], monthly_rating['rating_filled'], marker='o', color='navy')

# Rotate the x-axis labels and add a grid
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)

plt.title("Average Rating by Month-Year", fontsize=16)
plt.xlabel("Month-Year", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Note: You can use <font color="magenta">Seaborn</font>’s lineplot:

# %%
sns.lineplot(data=monthly_rating, x='month_year', y='rating_filled', marker='o', color='navy')
plt.xticks(rotation=45)
plt.title("Average Rating by Month-Year")
plt.xlabel("Month-Year")
plt.ylabel("Average Rating")
plt.show()

# %% [markdown]
# ### **3. 📊 Visualization Goal: Box Plot**
#
# A box plot shows the distribution of a numerical variable across different categories. Let’s examine <font color="green">rating</font> by <font color="green">category</font>.
#
# **Key Insights**
# - Spot differences in median rating by category.
# - Identify potential outliers within each category.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip 💡 palette

plt.xticks(rotation=45)
plt.title("Rating Distribution by Category", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Rating", fontsize=12)
plt.show()

# %% [markdown]
# - Home & Kitchen has a wider spread with several low-rated products, indicating possible quality inconsistencies.
# - Musical Instruments has the lowest median rating, suggesting customer dissatisfaction or unmet expectations.
# - this shows we can have some new market opportunities over here in these cattegories like home and musical

# %% [markdown]
# Note: <font color="greed">Matplotlib</font> has plt.boxplot, for similar plot

# %% [markdown]
# ### **4. 📊 Visualization Goal: Violin Plot**
#
# A violin plot is similar to a box plot but also shows the kernel density of the data. Let’s see the distribution of <font color="green">discounted_price</font> by <font color="green">rating_category</font>.
#
# **Key Insights**
# - Compare the spread of prices for different rating categories.
# - Check if there's a concentration of lower/higher prices in certain categories.

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='rating_category', y='discounted_price', inner='quartile', palette='Accent')

plt.title("Violin Plot of Discounted Price by Rating Category", fontsize=16)
plt.xlabel("Rating Category", fontsize=12)
plt.ylabel("Discounted Price", fontsize=12)
plt.show()

# %% [markdown]
# ### **5. 📊 Visualization Goal: Grouped Bar Plot**
#
# A grouped bar plot compares multiple categories side by side. Let’s compare the average <font color="green">rating</font> for products that do or do not contain the keyword "durable", across different <font color="green">rating_category</font>.
#
# **Key Insights**
# - Check how “durable” items perform in each rating category vs. non-durable.
# - Identify which group has higher/lower average ratings.

# %%
# Create a pivoted dataframe
grouped_data = df.groupby(['rating_category', 'contains_durable'])['rating_filled'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=grouped_data, x='rating_category', y='rating_filled', hue='contains_durable', palette='Paired')

# Styling Tip 💡
# Add legend title
plt.legend(title='Contains Durable?')

plt.title("Average Rating by Rating Category and Durability", fontsize=16)
plt.xlabel("Rating Category", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.show()

# %% [markdown]
# - since durable products tend to receive higher ratings, highlight durability features in product descriptions and marketing campaigns.
# - The "Poor" category consists only of non-durable products, reinforcing that low-quality, short-lived products tend to receive more negative feedback.

# %% [markdown]
# ---
# ## **4. Multivariate Plots (Three or More Variables)**

# %% [markdown]
# ### **1. 📊 Visualization Goal: Pair Plot**
#
# A pair plot visualizes pairwise relationships and distributions for multiple numerical variables. Let’s look at <font color="green">rating</font>, <font color="green">discounted_price</font>, and <font color="green">actual_price</font>.
#
# **Key Insights**
# - Quickly spot correlations.
# - View distributions on the diagonal.

# %%
sns.pairplot(df[['rating', 'discounted_price', 'actual_price', 'calculated_discount_filled']].dropna(),
             diag_kind='kde', corner=True, plot_kws={'alpha':0.5})
plt.show()

# %% [markdown]
# - notice the actual price and discounted price plots. we can assume that discounts are applied proportionally to the original price rather than randomly.
# - scatter between calculated_discount_filled and rating does not show a clear upward trend.
# - Mid-range products (₹10,000 - ₹30,000) tend to have higher discounts than extremely high-end or low-priced products.

# %% [markdown]
# ### **2. 📊 Visualization Goal: Heatmap**
#
# A heatmap is great for correlation matrices. Let’s see how <font color="green">rating</font>, <font color="green">discounted_price</font>, <font color="green">actual_price</font>, <font color="green">rating_count</font>, etc., correlate.
#
# **Key Insights**
# - Identify strong positive or negative correlations.
# - Guides feature selection or further analysis.

# %%
corr_cols = ['rating', 'discounted_price', 'actual_price', 'rating_count', 'calculated_discount']
corr_matrix = df[corr_cols].corr()

plt.figure(figsize=(8, 6))

# Styling Tip 💡
# Format annotation to 2 decimal places
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='Blues')

plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %% [markdown]
# - again discounted prices are directly proportional to actual prices, meaning discounts are percentage-based rather than fixed amounts.
# - Rating vs. Discounted Price (0.10) and Rating vs. Actual Price (0.11) show almost no correlation, meaning higher-priced products do not necessarily get better ratings.
# - Since high discounts do not lead to better ratings, businesses should prioritize improving product quality and customer service rather than relying on heavy discounts.
# - Since expensive products do not necessarily get higher ratings, consider adding value through better warranties, customer support, and post-purchase engagement to boost satisfaction.

# %% [markdown]
# ### **3. Subplots and hue**
#
# The **`hue`** parameter in <font color="magenta">Seaborn</font> allows us to color the data points (or bars, lines, etc.) by another categorical variable, giving a quick comparison without creating separate subplots or separate figures.
#
# **Example: Bar Plot with Hue**
#
# Let’s say we want to compare the **average rating** by **`rating_category`** for products that **do or do not contain “durable”**. We'll use the `contains_durable` column as the `hue` parameter.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Group by rating_category and contains_durable, then compute average rating
grouped_data = df.groupby(['rating_category', 'contains_durable'])['rating_filled'].mean().reset_index()

sns.barplot(
    data=grouped_data,
    x='rating_category',
    y='rating_filled',
    hue='contains_durable',
    palette='viridis'
)

# Styling Tip 💡
# Add a legend title and rotate x-axis labels
plt.legend(title='Durable?')
plt.xticks(rotation=45)
plt.title("Average Rating by Rating Category and Durability", fontsize=16)
plt.xlabel("Rating Category", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.show()

# %% [markdown]
# **Subplots with Different Hues**
#
# Sometimes, you may want multiple subplots side by side, each using a different hue variable. This can be useful if you have multiple categorical variables you want to highlight in separate views.
#
# **Example:** Two Scatter Plots with Different Hues
# - In the first subplot, we'll color by <font color="green">rating_category</font>.
# - In the second subplot, we’ll color by the <font color="green">price_range</font> column (imagine it categorizes items as “Budget”, “Mid-range”, “Premium”, etc.).

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Subplot 1: Hue by 'rating_category'
sns.scatterplot(
    data=df,
    x='discounted_price',
    y='rating_filled',
    hue='rating_category',
    ax=axes[0],
    palette='coolwarm'
)
axes[0].set_title("Discounted Price vs. Rating (Hue: Rating Category)", fontsize=14)
axes[0].set_xlabel("Discounted Price", fontsize=12)
axes[0].set_ylabel("Rating", fontsize=12)

# Subplot 2: Hue by 'price_range'
sns.scatterplot(
    data=df,
    x='discounted_price',
    y='rating_filled',
    hue='price_range',  # Alternatively: 'actual_price', binned, or another categorical col
    ax=axes[1],
    palette='Spectral'
)
axes[1].set_title("Discounted Price vs. Rating (Hue: Price Range)", fontsize=14)
axes[1].set_xlabel("Discounted Price", fontsize=12)
axes[1].set_ylabel("Rating", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# - low-priced products have both high and low ratings, indicating inconsistent quality.
# - should invest in quality assurance and ensure consistency in product descriptions and expectations.

# %% [markdown]
# ### **4. Stacked Plots**
#
# A stacked plot (most commonly a stacked bar plot) allows you to see parts of a whole for different categories on top of each other.
#
# **1 Stacked Bar Plot**
# Let’s say we want to visualize how rating_category is distributed within each <font color="green">price_range</font> category. This will show each price_range on the x-axis and “stack” the segments of rating categories in each bar.
#
# Steps:
# - Compute counts of reviews (or any metric) grouped by price_range and rating_category.
# - Unstack the grouped data so each rating_category becomes a separate column.
# - Use <font color="skyblue">Matplotlib</font> (pandas plotting) with stacked=True.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Group by price_range and rating_category, and get counts
grouped_stack = df.groupby(['price_range', 'rating_category'])['review_id'].count().unstack()

# 2. Plot as stacked bar
grouped_stack.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    colormap='Blues'
)

# Styling Tip 💡
plt.title("Stacked Bar Plot: Rating Categories by Price Range", fontsize=16)
plt.xlabel("Price Range", fontsize=12)
plt.ylabel("Number of Reviews", fontsize=12)
plt.legend(title="Rating Category")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Encourage More Reviews for High & Very High-Priced Products
# - identify patterns in negative reviews of low-priced products and address recurring complaints to reduce refund rates and improve trust.

# %% [markdown]
# Note: A stacked bar plot can become hard to read if there are many categories. In such cases, a grouped bar chart or a different type of visualization might be more suitable.
#
#
#
# ---

# %% [markdown]
# ## **5. Conclusion**
#
#
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/272/original/Screenshot_2024-12-27_103544.png?1735275986)

# %% [markdown]
# Visualization is about **asking the right question** and **picking the right plot** for both your **data** and your **audience**. We’ve covered a range of plots—univariate, bivariate, and multivariate—and explored how to add extra dimensions via **hue**, **subplots**, and **stacked** techniques.
#
# - **Focus on the story** you want to tell; each plot should highlight a key insight or pattern.
# - **Keep it simple**: avoid clutter, label axes clearly, and use color thoughtfully.
# - **Know your audience**: are they familiar with complex plots, or do they prefer simpler visualizations?
# - **Iterate**: no single plot is perfect; try multiple approaches to see what communicates insights best.
#
# **Remember**: A plot is only as powerful as the **question** it helps answer. Combine clarity, audience awareness, and the right techniques to deliver compelling data stories.
#
# **Happy plotting!**
#
# ---

# %% [markdown]
# **Instructor Note**
#
# Open this cheetsheet at the end of the lecture to answer questions, if you have time [link](https://drive.google.com/file/d/1EDV3aiBRzw8zgGD7i0wj3mmCWOt541P4/view)
