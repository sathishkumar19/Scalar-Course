# %%
import numpy as np
import pandas as pd
import seaborn as sb

# !pip install xlrd

# %%
df = pd.read_excel('/Users/ssathishkumar/Library/CloudStorage/OneDrive-kyndryl/data/learning/Scalar-Course/datasets/datasets/pandas/SampleSuperstore.xls')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
findval = df[['Sales','Profit','Quantity']]
findval
# Out:
#          Sales    Profit  Quantity
# 0     261.9600   41.9136         2
# 1     731.9400  219.5820         3
# 2      14.6200    6.8714         2
# 3     957.5775 -383.0310         5
# 4      22.3680    2.5164         2
# ...        ...       ...       ...
# 9989   25.2480    4.1028         3
# 9990   91.9600   15.6332         2
# 9991  258.5760   19.3932         2
# 9992   29.6000   13.3200         4
# 9993  243.1600   72.9480         2
#
# [9994 rows x 3 columns]

# %%
findval.describe()
# Out:
#               Sales       Profit     Quantity
# count   9994.000000  9994.000000  9994.000000
# mean     229.858001    28.656896     3.789574
# std      623.245101   234.260108     2.225110
# min        0.444000 -6599.978000     1.000000
# 25%       17.280000     1.728750     2.000000
# 50%       54.490000     8.666500     3.000000
# 75%      209.940000    29.364000     5.000000
# max    22638.480000  8399.976000    14.000000

# %%
df['Sales_new'] = df['Sales'].fillna(0)
df['Sales_new']
#df['Sales_new'].median()
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales_new, Length: 9994, dtype: float64

# %%
df['Profit_Margin'] = df['Profit']/df['Sales']
df['Profit_Margin']
# Out:
# 0       0.1600
# 1       0.3000
# 2       0.4700
# 3      -0.4000
# 4       0.1125
#          ...
# 9989    0.1625
# 9990    0.1700
# 9991    0.0750
# 9992    0.4500
# 9993    0.3000
# Name: Profit_Margin, Length: 9994, dtype: float64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Sales_new',
#        'Profit_Margin'],
#       dtype='object')

# %%
sb.countplot(x='Category', data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sb.scatterplot(x='Sales', y='Profit', data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sb.scatterplot(x='Sales',y='Profit',data=df,hue='Sub-Category')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sb.scatterplot(x='Sales',y='Profit',data=df,hue='Segment')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
# Numpy Sections

# %%
#Sort it in descending order
df.groupby(["Category"])['Sales'].mean().sort_values(ascending=False)
# Out:
# Category
# Technology         452.709276
# Furniture          349.834887
# Office Supplies    119.324101
# Name: Sales, dtype: float64

# %%
# get the category with max sales
df.groupby(["Category"])['Sales'].mean().sort_values(ascending=False).head(1)
# Out:
# Category
# Technology    452.709276
# Name: Sales, dtype: float64

# %%
# get the category with max average sales and pick the top 1
df.groupby(["Category"])['Sales'].mean().sort_values(ascending=False).head(1)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Sales_new',
#        'Profit_Margin'],
#       dtype='object')

# %%
# find the sub-category with max profit

df.groupby(["Sub-Category"])['Profit'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
df[df['Profit']>50]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11        12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 13        14  CA-2016-161389 2016-12-05 2016-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 9968    9969  CA-2017-153871 2017-12-11 2017-12-17  Standard Class
# 9970    9971  CA-2015-103772 2015-06-28 2015-07-02  Standard Class
# 9979    9980  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID    Customer Name      Segment        Country         City  \
# 1       CG-12520      Claire Gute     Consumer  United States    Henderson
# ...

# %%
x= df[['Profit', 'Sales', 'Quantity', 'Category']]
sb.pairplot(x, hue='Category')
